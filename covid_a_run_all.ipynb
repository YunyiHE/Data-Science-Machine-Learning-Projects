# %%
# %run covid_a_master_cumulative_table.ipynb
# Out:
# C:\Users\nikan\Desktop\COVID_daily\COVID-19-geographic-disbtribution-worldwide-2020-08-03.xlsx

# %%
# %run covid_b_cases_cumulative_analysis.ipynb
# Out:
# The average infection rate is: 4127.6 per 1m people
# The average death rate is: 161.9 per 1m people
# The average mortality rate is: 3.9 per 100 people infected

# %%
# %run covid_c_mortalities_cumulative_analysis.ipynb

# %%
# %run covid_d_infection_rate_profiles.ipynb

# %%
# %run covid_e_mortality_rate_profiles.ipynb

# %%
# %run covid_f_static_rates_correlations.ipynb

# %%
# %run covid_g_static_rates_correlations_bokeh.ipynb
# Out:
# The average infection rate is: 2958.4 per 1m people
# The average death rate is: 115.2 per 1m people
# The average mortality rate is: 3.9 per 100 people infected

# %%
# %run covid_h_master_continent_cumulative.ipynb
# Out:
# C:\Users\nikan\Desktop\COVID_daily\COVID-19-geographic-disbtribution-worldwide-2020-08-03.xlsx
# C:\Users\nikan\Anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
